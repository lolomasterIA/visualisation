# %% [markdown]
# #### Attention:
# Ceci ne prend pas en compte les départements d'outre mer mais uniquement la métrople !! (je n'ai pas trouvé de carte fonctionnel)

# %%
# %pip install altair pandas numpy plotly geopandas requests
import altair as alt 
alt.data_transformers.enable('json')
# Out:
# Requirement already satisfied: altair in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (5.5.0)
# Requirement already satisfied: pandas in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (2.3.0)
# Requirement already satisfied: numpy in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (2.3.1)
# Requirement already satisfied: plotly in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (6.1.2)
# Requirement already satisfied: geopandas in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (1.1.0)
# Requirement already satisfied: requests in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (2.32.4)
# Requirement already satisfied: jinja2 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from altair) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from altair) (4.24.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from altair) (1.44.0)
# Requirement already satisfied: packaging in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from altair) (25.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from altair) (4.14.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: pyogrio>=0.7.2 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from geopandas) (0.11.0)
# Requirement already satisfied: pyproj>=3.5.0 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from geopandas) (3.7.1)
# Requirement already satisfied: shapely>=2.0.0 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from geopandas) (2.1.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from requests) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from requests) (2025.6.15)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from jsonschema>=3.0->altair) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from jsonschema>=3.0->altair) (2025.4.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from jsonschema>=3.0->altair) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from jsonschema>=3.0->altair) (0.25.1)
# Requirement already satisfied: six>=1.5 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\josep\documents\telecom paris\visualisation\visualisation\venv_visu\lib\site-packages (from jinja2->altair) (3.0.2)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# DataTransformerRegistry.enable('json')

# %%
import pandas as pd
import plotly.graph_objs as go
import numpy as np

# %%
df = pd.read_csv("data/dpt2020.csv", sep=";")

# Vérifier si '2A' ou '2B' sont présents
print("'2A' présent ?", '2A' in df['dpt'].unique())
print("'2B' présent ?", '2B' in df['dpt'].unique())
# Out:
# '2A' présent ? False
# '2B' présent ? False

# %%
print(f"Initial shape is {df.shape}")

# supp years and dpt = XXXX and transform to int
to_clean=['annais', 'dpt']
for col in to_clean:
    #df[col] = df[col].astype(str).str.strip()
    
    # Supprimer les lignes où la colonne n'est pas strictement numérique
    df = df[df[col].str.isnumeric()]
    
    if col == 'annais':
        df[col] = df[col].astype(int)
        
    else:
    # Reforcer le type string natif (facultatif mais propre)
        df[col] = df[col].astype("string")
        
        ### Ce n'est pas supported par la carte que nous avons ###
        # Transformation pour la corse => tout est transformé en 2A
        df.loc[df['dpt'] == '20', 'dpt'] = '2A'
        # Exclusion des DOM_TOM
        df = df[~df['dpt'].isin(['971', '972', '973', '974'])]
    print(df[col].dtype)
    print(f"Shape is now {df.shape}")
# Out:
# Initial shape is (3727553, 5)
# int64
# Shape is now (3690309, 5)
# string
# Shape is now (3492154, 5)

# %%
# Supprimer les prénoms "_PRENOMS_RARES"
df = df[df["preusuel"] != "_PRENOMS_RARES"]
# Ajouter une colonne de longueur de prénom
df["longueur"] = df["preusuel"].str.len()
# Supprimer les prénoms de longueur 1
df = df[df["longueur"] > 1]
print(f"Shape is now {df.shape}")
# Out:
# Shape is now (3471072, 6)

# %%
df
# Out:
#          sexe preusuel  annais dpt  nombre  longueur
# 10885       1    AADIL    1983  84       3         5
# 10886       1    AADIL    1992  92       3         5
# 10888       1    AAHIL    2016  95       3         5
# 10892       1    AARON    1962  75       3         5
# 10893       1    AARON    1976  75       3         5
# ...       ...      ...     ...  ..     ...       ...
# 3727543     2      ZYA    2011  91       3         3
# 3727545     2      ZYA    2013  44       4         3
# 3727546     2      ZYA    2013  59       3         3
# 3727548     2      ZYA    2018  59       3         3
# 3727550     2     ZYNA    2013  93       3         4
#
# [3471072 rows x 6 columns]

# %%
max_nombre = df.groupby(['sexe', 'annais', 'dpt'])['nombre'].transform('max')
df_final = df[df['nombre'] == max_nombre]
# Tri décroissant puis suppression des duplicatas
df_final = (
    df.sort_values('nombre', ascending=False)
      .drop_duplicates(['sexe', 'annais', 'dpt'])
      .sort_values(by=['sexe', 'annais', 'dpt'])
)
moyenne_longueur = df.groupby(['sexe', 'annais', 'dpt'])['longueur'].transform('mean').round().astype(int)
df_final['moyenne_longueur'] = moyenne_longueur

# %%
df_final
# Out:
#          sexe preusuel  annais dpt  nombre  longueur  moyenne_longueur
# 770685      1     JEAN    1900  01     144         4                 6
# 114883      1    ANDRÉ    1900  02     138         5                 6
# 770687      1     JEAN    1900  03     230         4                 6
# 1023835     1    LOUIS    1900  04      40         5                 6
# 900377      1   JOSEPH    1900  05      50         6                 6
# ...       ...      ...     ...  ..     ...       ...               ...
# 2864122     2     LINA    2020  91      69         4                 5
# 2377520     2     EMMA    2020  92     132         4                 6
# 2864124     2     LINA    2020  93     101         4                 6
# 2864125     2     LINA    2020  94      87         4                 6
# 2864126     2     LINA    2020  95      88         4                 5
#
# [22310 rows x 7 columns]

# %%
df_final[(df_final['annais'] == 2018) & (df_final['dpt'] == '46')]
# Out:
#          sexe preusuel  annais dpt  nombre  longueur  moyenne_longueur
# 983512      1      LÉO    2018  46      10         3                 5
# 2816747     2      LÉA    2018  46       6         3                 4

# %%
import geopandas as gpd
from io import BytesIO
import requests

#Préparation de la carte
url = "https://france-geojson.gregoiredavid.fr/repo/departements.geojson"
response = requests.get(url)
response.raise_for_status()
gdf = gpd.read_file(BytesIO(response.content))
gdf["geometry"] = gdf["geometry"].simplify(0.01)

dep = gdf.merge(df_final, how='right', left_on='code', right_on='dpt')
dep['moyenne_longueur'] = dep['moyenne_longueur'].fillna(0).astype(int)
dep = dep.dropna(subset=['geometry'])

# %%
#Widget pour la carte
# Paramètre pour l'année (avec un slider)
year_param = alt.selection_point(
    fields=["annais"],
    bind=alt.binding_range(
        min=dep['annais'].min(),
        max=dep['annais'].max(),
        step=1,
    name="Année :"
    ),
    value=dep['annais'].min()
)

# Paramètre pour le sexe (avec bouton radio)
gender_param = alt.selection_point(
    fields=["sexe"],
    bind=alt.binding_radio(
        name="Sexe :", 
        options=[1, 2],
        labels=['♂ Homme', '♀ Femme']
    ),
    value=1
)

# Paramètre pour la longueur (avec liste déroulante)
length_param = alt.selection_point(
    fields=["moyenne_longueur"], 
    bind=alt.binding_select(
        options=sorted(dep["moyenne_longueur"].dropna().unique()), 
        name="Longueur moyenne : "
    ),
    value=dep["moyenne_longueur"].iloc[0]  # Valeur par défaut
)

carte = alt.Chart(dep).mark_geoshape(
    stroke='white'
).encode(
    color=alt.Color("moyenne_longueur:Q", scale=alt.Scale(scheme='viridis'), title="Longueur moyenne"),
    tooltip=[
        alt.Tooltip("nom:N", title="Département"),
        alt.Tooltip("code:N", title="Code"),
        alt.Tooltip("moyenne_longueur:Q", title="Longueur moyenne du prénom"),
        alt.Tooltip("preusuel:N", title="Prénom le plus populaire")]
).add_params(
    gender_param,
    year_param
).transform_filter(
    gender_param,
    year_param
).project(
    type='mercator'
).properties(
    width=600,
    height=600
)

carte
# Out:
# c:\Users\josep\Documents\Telecom Paris\visualisation\visualisation\venv_visu\Lib\site-packages\altair\utils\core.py:461: UserWarning: Geometry column does not contain geometry.
#   df[col_name] = col.where(col.notnull(), None)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File c:\Users\josep\Documents\Telecom Paris\visualisation\visualisation\venv_visu\Lib\site-packages\altair\vegalite\v5\api.py:4033, in Chart.to_dict(self, validate, format, ignore, context)
#    4031     copy.data = core.InlineData(values=[{}])
#    4032     return super(Chart, copy).to_dict(**kwds)
# -> 4033 return super().to_dict(**kwds)
#
# File c:\Users\josep\Documents\Telecom Paris\visualisation\visualisation\venv_visu\Lib\site-packages\altair\vegalite\v5\api.py:1998, in TopLevelMixin.to_dict(self, validate, format, ignore, context)
#    1995     except TypeError:
#    1996         # Non-narwhalifiable type supported by Altair, such as dict
#    1997         data = original_data
# -> 1998     copy.data = _prepare_data(data, context)
#    1999     context["data"] = data
#    2001 # remaining to_dict calls are not at top level
#
# File c:\Users\josep\Documents\Telecom Paris\visualisation\visualisation\venv_visu\Lib\site-packages\altair\vegalite\v5\api.py:283, in _prepare_data(data, context)
#     281 elif not isinstance(data, dict) and _is_data_type(data):
#     282     if func := data_transformers.get():
# --> 283         data = func(nw.to_native(data, pass_through=True))
#     285 # convert string input to a URLData
#     286 elif isinstance(data, str):
#
# File c:\Users\josep\Documents\Telecom Paris\visualisation\visualisation\venv_visu\Lib\site-packages\altair\utils\data.py:260, in to_json(data, prefix, extension, filename, urlpath)
#     258     return partial(to_json, **kwds)
#     259 else:
# --> 260     data_str = _data_to_json_string(data)
#     261     return _to_text(data_str, **kwds, format=_FormatDict(type="json"))
#
# File c:\Users\josep\Documents\Telecom Paris\visualisation\visualisation\venv_visu\Lib\site-packages\altair\utils\data.py:376, in _data_to_json_string(data)
#     374 check_data_type(data)
#     375 if isinstance(data, SupportsGeoInterface):
# --> 376     return json.dumps(_from_geo_interface(data))
#     377 elif is_pandas_dataframe(data):
#     378     data = sanitize_pandas_dataframe(data)
#
# File c:\Users\josep\Documents\Telecom Paris\visualisation\visualisation\venv_visu\Lib\site-packages\altair\utils\data.py:369, in _from_geo_interface(data)
#     367 if is_pandas_dataframe(data):
#     368     data = sanitize_pandas_dataframe(data)
# --> 369 return sanitize_geo_interface(data.__geo_interface__)
#
# File c:\Users\josep\Documents\Telecom Paris\visualisation\visualisation\venv_visu\Lib\site-packages\pandas\core\generic.py:6318, in NDFrame.__getattr__(self, name)
#    6311 if (
#    6312     name not in self._internal_names_set
#    6313     and name not in self._metadata
#    6314     and name not in self._accessors
#    6315     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6316 ):
#    6317     return self[name]
# -> 6318 return object.__getattribute__(self, name)
#
# File c:\Users\josep\Documents\Telecom Paris\visualisation\visualisation\venv_visu\Lib\site-packages\geopandas\geodataframe.py:1089, in GeoDataFrame.__geo_interface__(self)
#    1057     @property
#    1058     def __geo_interface__(self) -> dict:
#    1059         """Returns a ``GeoDataFrame`` as a python feature collection.
#    1060
#    1061         Implements the `geo_interface`. The returned python data structure
#    (...)   1087 box': (2.0, 1.0, 2.0, 1.0)}], 'bbox': (1.0, 1.0, 2.0, 2.0)}
#    1088         """
# -> 1089         return self.to_geo_dict(na="null", show_bbox=True, drop_id=False)
#
# File c:\Users\josep\Documents\Telecom Paris\visualisation\visualisation\venv_visu\Lib\site-packages\geopandas\geodataframe.py:1251, in GeoDataFrame.to_geo_dict(self, na, show_bbox, drop_id)
#    1201 def to_geo_dict(
#    1202     self, na: str | None = "null", show_bbox: bool = False, drop_id: bool = False
#    1203 ) -> dict:
#    1204     """
#    1205     Returns a python feature collection representation of the GeoDataFrame
#    1206     as a dictionary with a list of features based on the ``__geo_interface__``
#    (...)   1247
#    1248     """
#    1249     geo = {
#    1250         "type": "FeatureCollection",
# -> 1251         "features": list(
#    1252             self.iterfeatures(na=na, show_bbox=show_bbox, drop_id=drop_id)
#    1253         ),
#    1254     }
#    1256     if show_bbox:
#    1257         geo["bbox"] = tuple(self.total_bounds.tolist())  # tolist to avoid np dtypes
#
# File c:\Users\josep\Documents\Telecom Paris\visualisation\visualisation\venv_visu\Lib\site-packages\geopandas\geodataframe.py:1178, in GeoDataFrame.iterfeatures(self, na, show_bbox, drop_id)
#    1176 feature["type"] = "Feature"
#    1177 feature["properties"] = properties_items
# -> 1178 feature["geometry"] = mapping(geom) if geom else None
#    1180 if show_bbox:
#    1181     feature["bbox"] = geom.bounds if geom else None
#
# File c:\Users\josep\Documents\Telecom Paris\visualisation\visualisation\venv_visu\Lib\site-packages\shapely\geometry\geo.py:143, in mapping(ob)
#     121 def mapping(ob):
#     122     """Return a GeoJSON-like mapping.
#     123
#     124     Input should be a Geometry or an object which implements __geo_interface__.
#    (...)    141
#     142     """
# --> 143     return ob.__geo_interface__
#
# AttributeError: 'dict' object has no attribute '__geo_interface__'
# alt.Chart(...)

# %%
dep[(dep['annais'] == 2018) & (dep['dpt'] == '46')]
# Out:
#       code  nom                                           geometry  sexe  \
# 10915   46  Lot  POLYGON ((1.40926 45.006, 1.53572 45.04628, 1....     1
# 22070   46  Lot  POLYGON ((1.40926 45.006, 1.53572 45.04628, 1....     2
#
#       preusuel  annais dpt  nombre  longueur  moyenne_longueur
# 10915  GABRIEL    2018  46      10         7                 5
# 22070      LÉA    2018  46       6         3                 4
